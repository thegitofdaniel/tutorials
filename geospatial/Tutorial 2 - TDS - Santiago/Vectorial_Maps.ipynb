# %% [markdown]
# # Census 2017

# %%
# Out:
# (52, 7)

# %%
census_17.head()
# Out:
#    COMUNA   NOM_COMUNA  INMIGRANTES  PERSONAS   INM_PERC  TOTAL_VIV  PERS_VIV
# 0   13101     santiago       110732    404495  27.375369     193628  2.089032
# 1   13102    cerrillos         3620     80832   4.478424      24547  3.292948
# 2   13103  cerro navia         6022    132622   4.540725      38020  3.488217
# 3   13104     conchali         9223    126955   7.264779      37759  3.362245
# 4   13105    el bosque         3368    162505   2.072552      47941  3.389687

# %%
# Out:
# 1: 6444 => 36070
# 2: 36071 => 90200
# 3: 90201 => 101603
# 4: 101604 => 132621
# 5: 132622 => 209322
# 6: 209323 => 568105
#
#    1   2   3   4   5   6
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   del sys.path[0]

# %%
help(isStr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-7a2f4ac68d06> in <module>
# ----> 1 help(isStr)
#
# NameError: name 'isStr' is not defined

# %% [markdown]
# ---
